# %%
import sys
sys.path.insert(0, "..")

# %%
from tools.cogencis import CogencisClient

# %%
cc = CogencisClient(
    bearer_token='eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJleHAiOjE3NjgyNDE0MTcsImRhdGEiOnsidXNlcl9pZCI6NzY1LCJhcHBzIjoiY21zLHJhcGksY21zLHJhcGksY21zLHJhcGkiLCJyb2xlcyI6InZpZXcifSwiaWF0IjoxNzY4MTU1MDE3fQ.evz_2gEQ2ahRZn-GQXN3S7yuaPG3tLo99zEXV1Jp6Nk',
    base_url='https://data.cogencis.com/api/v1'
)

# %%
lr = cc.symbol_lookup("RELIANCE")

# %%
lr
# Out:
# [SymbolData(symbol='RELIBROA.NS', isin='INE445K01018', company_name='Reliance Broadcast Network Ltd.', symbol_type='S', last_price=69.05, price_change=0.0, percent_change=0.0, path='ine445k01018/relibroa/ns/rbn/reliance-broadcast-network'),
#  SymbolData(symbol='RELICAPI.NS', isin='INE013A01015', company_name='Reliance Capital Ltd.', symbol_type='S', last_price=12.35, price_change=0.0, percent_change=0.0, path='ine013a01015/relicapi/ns/relcapital/reliance-capital_'),
#  SymbolData(symbol='RELICHEM.NS', isin='INE750D01016', company_name='Reliance Chemotex Industries Ltd.', symbol_type='S', last_price=137.4, price_change=0.19, percent_change=0.14, path='ine750d01016/relichem/ns/relchemq/reliance-chemotex-industries_'),
#  SymbolData(symbol='RELICOMM.NS', isin='INE330H01018', company_name='Reliance Communications Ltd.', symbol_type='S', last_price=1.07, price_change=-0.01, percent_change=-0.93, path='ine330h01018/relicomm/ns/rcom/reliance-communications_'),
# ...

# %%
reliance = lr[6]

# %%
cc.get_announcements(reliance.path)
# Out:
# [Announcement(datetime_str='2025-12-04T20:47:05', details='Credit Rating', pdf_link='https://nsearchives.nseindia.com/corporate/kavinavora_04122025204141_RIL_SE04122025.pdf', path='ine002a01018/relindus/ns/relindus.ns/reliance-industries_'),
#  Announcement(datetime_str='2025-12-04T19:13:58', details='Action(S) Taken Or Orders Passed', pdf_link='https://nsearchives.nseindia.com/corporate/kavinavora_04122025191311_SE_04122025.pdf', path='ine002a01018/relindus/ns/relindus.ns/reliance-industries_'),
#  Announcement(datetime_str='2025-11-17T19:53:26', details='Updates', pdf_link='https://nsearchives.nseindia.com/corporate/kavinavora_17112025195212_SE_17112025.pdf', path='ine002a01018/relindus/ns/relindus.ns/reliance-industries_'),
# ...

# %%
cc.get_insider_trades(reliance.path)
# Out:
# [InsiderTrade(date='14 Dec 23', acquirer_name='SHOBHA AGARWAL', category='Immediate relative', shares_before=731905.0, percentage_before=0.01, quantity=150000, transaction_type='Sell', shares_after=581905.0, percentage_after=0.01, acquisition_mode='Gift', path='ine002a01018/relindus/ns/reliance/reliance-industries_'),
#  InsiderTrade(date='29 Nov 23', acquirer_name='DIPALI AJAY KEER', category='Immediate relative', shares_before=2133.0, percentage_before=0.0, quantity=933, transaction_type='Sell', shares_after=1200.0, percentage_after=0.0, acquisition_mode='Market Sale', path='ine002a01018/relindus/ns/reliance/reliance-industries_'),
# ...

# %%
report = cc.get_full_report_markdown(reliance)

# %%
from IPython.display import display, Markdown

# %%
display(Markdown(report))
# Out:
# # Reliance Industries Ltd.
#
# *Generated Report - All data from Cogencis API*
#
# ---
#
# ## 📊 Overview
#
# | Field | Value |
# |-------|-------|
# | **Company Name** | Reliance Industries Ltd. |
# | **Symbol** | RELINDUS |
# | **ISIN** | INE002A01018 |
# | **Exchange** | NS |
# | **Last Price** | ₹1,475.30 |
# | **Change** | 📈 ₹4.70 (+0.32%) |
#
# ## 👥 Key Shareholders
#
# ### Promoters
#
# | Name | Holding (%) |
# |------|------------|
# | Srichakra Commercials Llp | 11.13% |
# | Devarshi Commercials Llp | 8.21% |
# | Karuna Commercials Llp | 8.21% |
# | Tattvam Enterprises Llp | 8.21% |
# | Reliance Industries Holding Private Ltd | 4.58% |
# | Petroleum Trust (Through Trustees For Sole Beneficiary-M/S Reliance Industrial Investments And Holdings Ltd) | 3.63% |
# | Reliance Services & Holdings Ltd,A Comp Controlled By Petroleum Trust,Sole Beneficiary Of Which Is Reliance Industrial Investments & Holdings Ltd | 2.59% |
# | Samarjit Enterprises Llp | 1.88% |
# ...

# %%
from tools.screener import ScreenerClient

# %%
sc = ScreenerClient()

# %%
res = sc.search("reliance")

# %%
res
# Out:
# CompanySearchResponse(results=[CompanySearchResult(id=2726, name='Reliance Industries Ltd', url='/company/RELIANCE/consolidated/'), CompanySearchResult(id=2729, name='Reliance Power Ltd', url='/company/RPOWER/consolidated/'), CompanySearchResult(id=2727, name='Reliance Infrastructure Ltd', url='/company/RELINFRA/consolidated/'), CompanySearchResult(id=2724, name='Reliance Communications Ltd', url='/company/RCOM/consolidated/'), CompanySearchResult(id=1274143, name='Reliance Home Finance Ltd', url='/company/RHFL/'), CompanySearchResult(id=2725, name='Reliance Industrial Infrastructure Ltd', url='/company/RIIL/consolidated/'), CompanySearchResult(id=2723, name='Reliance Chemotex Industries Ltd', url='/company/RELCHEMQ/'), CompanySearchResult(id=1274758, name='Reliance Industries Ltd Partly Paidup', url='/company/RELIANCEP1/'), CompanySearchResult(id=None, name='Search everywhere: reliance', url='/full-text-search/?q=reliance')])

# %%
res.results[0]
# Out:
# CompanySearchResult(id=2726, name='Reliance Industries Ltd', url='/company/RELIANCE/consolidated/')

# %%
ril = res.results[0]

# %%
ril.symbol
# Out:
# 'RELIANCE'

# %%
ril_page = sc.get_company_page(ril.symbol)

# %%
from IPython.display import display, Markdown

# %%
display(Markdown(ril_page))
# Out:
# Reliance Industries Ltd share price | About Reliance Industr | Key Insights - Screener
#
# window.plausible = window.plausible || function () { (window.plausible.q = window.plausible.q || []).push(arguments) }
#
# .persistent-messages:has(.show-on-company-page),
# .show-on-company-page.hidden {
# display: block;
# }
# tr[data-row-company-id="2726"] {
# font-weight: 500;
# }
# tr[data-row-company-id="2726"] a {
# color: var(--ink-900);
# }
# :target {
# scroll-margin-top: 90px;
# }
# @supports not (scroll-margin-top: 90px) {
# :target {
# padding-top: 108px;
# }
# }
# @media (min-width: 992px) {
# nav {
# margin-bottom: 0;
# }
# .company-nav {
# top: 50px;
# margin-bottom: 24px;
# }
# }
#
# * [Home](/)
# * [Screens](/explore/)
# * Tools
# * [Login](/register/?)
#
# [![Screener Logo](https://cdn-static.screener.in/img/logo-black.f44abb4998d1.svg)](/)
#
# [Home](/)
# [Screens](/explore/)
#
# Tools
#
# ...

# %%
sc.get_price_chart(ril.id)
# Out:
# ChartResponse(datasets=[ChartDataset(metric='Price', label='Price on NSE', values=[ChartDataPoint(data_date=datetime.date(2025, 1, 13), value=1239.85, extra=None), ChartDataPoint(data_date=datetime.date(2025, 1, 14), value=1238.75, extra=None), ChartDataPoint(data_date=datetime.date(2025, 1, 15), value=1252.2, extra=None), ChartDataPoint(data_date=datetime.date(2025, 1, 16), value=1266.45, extra=None), ChartDataPoint(data_date=datetime.date(2025, 1, 17), value=1302.35, extra=None), ChartDataPoint(data_date=datetime.date(2025, 1, 20), value=1305.45, extra=None), ChartDataPoint(data_date=datetime.date(2025, 1, 21), value=1273.7, extra=None), ChartDataPoint(data_date=datetime.date(2025, 1, 22), value=1277.1, extra=None), ChartDataPoint(data_date=datetime.date(2025, 1, 23), value=1263.65, extra=None), ChartDataPoint(data_date=datetime.date(2025, 1, 24), value=1246.3, extra=None), ChartDataPoint(data_date=datetime.date(2025, 1, 27), value=1229.35, extra=None), ChartDataPoint(data_date=dat
# ...

# %%
sc.get_market_cap_chart(ril.id)
# Out:
# ---------------------------------------------------------------------------
# ScreenerNotFoundError                     Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 sc.get_market_cap_chart(ril.id)
#
# File ~/Projects/hagrid-ai/notebooks/../tools/screener/client.py:260, in ScreenerClient.get_market_cap_chart(self, company_id, days, consolidated)
#     243 def get_market_cap_chart(
#     244     self,
#     245     company_id: int,
#     246     days: int = 10000,
#     247     consolidated: bool = True,
#     248 ) -> ChartResponse:
#     249     """
#     250     Get market cap to sales ratio chart.
#     251
#    (...)    258         ChartResponse with Market Cap/Sales, Median, Sales datasets
#     259     """
# --> 260     return self.get_chart(
#     261         company_id=company_id,
#     262         query=ValuationChartQuery.MARKET_CAP_SALES.value,
#     263         days=days,
#     264         consolidated=consolidated,
#     265     )
#
# ...
